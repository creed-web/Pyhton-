# %%
print("Hello from Jupyter in VS Code!")
# Out:
# Hello from Jupyter in VS Code!

# %%
import math

# %%
from math import *
print(sqrt(81))
# Out:
# 9.0

# %%
from Packages.math import addition
addition(3,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 from Packages.math import *
#       2 addition(3,4)
# ----> 3 subtraction(4,1)
#
# NameError: name 'subtraction' is not defined
